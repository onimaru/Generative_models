# %% [markdown]
# # Regularized Autoencoder
#
# L = MSE

# %%
import numpy as np
import torch
import torch.utils.data
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.autograd import Variable
from torchvision import datasets, transforms
from torchvision.utils import make_grid , save_image
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
architecture_name = "regularized_autoencoder"
ngpu=1
device = torch.device("cuda:0" if (torch.cuda.is_available() and ngpu > 0) else "cpu")
device
# Out:
# device(type='cuda', index=0)

# %%
def create_loader(data_path,workers,batch_size):
    dataset = datasets.ImageFolder(root=data_path,
                                     transform=transforms.Compose([transforms.ToTensor()]))
    loader = torch.utils.data.DataLoader(dataset, batch_size=batch_size,
                                         shuffle=True, num_workers=workers)
    return loader

# %% [markdown]
# ### Usando weight_decay do Adam

# %%
class Net(nn.Module):
    def __init__(self,input_dim=784,output_dim=784,ngpu=ngpu):
        super(Net, self).__init__()
        self.input_dim = input_dim
        self.output_dim = output_dim
        self.hidden1 = nn.Linear(self.input_dim, self.output_dim)
        self.act1 = nn.ReLU()
        self.hidden2 = nn.Linear(self.output_dim, self.output_dim)
        self.act2 = nn.ReLU()
        self.out1 = nn.Linear(self.output_dim, self.output_dim)

    def forward(self, x):
        h = self.act1(self.hidden1(x))
        h = self.act2(self.hidden2(h))
        out = torch.sigmoid(self.out1(h))
        return out

def init_weights(m):
    if type(m) == nn.Linear:
        torch.nn.init.xavier_normal_(m.weight).to(device)
        m.bias.data.fill_(0.001)
    
def define_model(model_class,input_dim):
    # Instanciamos as redes
    net = model_class(input_dim).to(device)
    if (device.type == 'cuda') and (ngpu > 1):
        net = nn.DataParallel(net, list(range(ngpu)))

    # Inicializamos os pesos
    net.apply(init_weights)

    learning_rate, beta1, beta2 = [1e-3,0.5,0.999]
    eps,weight_decay,amsgrad = [1e-8,1e-5,False]
    net_optimizer = optim.Adam(net.parameters(),
                               lr=learning_rate,
                               betas=(beta1,beta2),
                               eps=eps,
                               weight_decay=weight_decay, # regularization: https://pytorch.org/docs/stable/_modules/torch/optim/adam.html#Adam
                               amsgrad=amsgrad)
    return net,net_optimizer

mse_loss = nn.MSELoss()

# %%
workers      = 12
batch_size   = 32
img_size     = 28
X_dim        = 784
h_dim        = 100
train_loader = create_loader("/home/ninja/MNIST/training/",workers,batch_size)
test_loader  = create_loader("/home/ninja/MNIST/testing/" ,workers,batch_size)

net,net_optimizer = define_model(Net,X_dim)

# %%
for epoch in range(10):
    loss_ = []
    for _, (X_train,_) in enumerate(train_loader):
        X_train = X_train.view(-1,784).to(device)
        X_pred_train = net(X_train)
        loss = mse_loss(X_pred_train,X_train)
        loss.backward()
        net_optimizer.step()
        net_optimizer.zero_grad()

    print("Training loss for {} epoch: {}".format(epoch, loss))
# Out:
# Training loss for 0 epoch: 0.003389563411474228
# Training loss for 1 epoch: 0.0026320372708141804
# Training loss for 2 epoch: 0.0026868379209190607
# Training loss for 3 epoch: 0.0020806659013032913
# Training loss for 4 epoch: 0.002470430452376604
# Training loss for 5 epoch: 0.0024064499884843826
# Training loss for 6 epoch: 0.0018995144637301564
# Training loss for 7 epoch: 0.0023201939184218645
# Training loss for 8 epoch: 0.001957884058356285
# Training loss for 9 epoch: 0.0018514868570491672

# %%
def show_img(title,img,size = 32,img_size=28):
    print(title)
    img = img[:size].cpu().view(size,1,img_size,img_size)
    npimg = np.transpose(make_grid(img).numpy(),(1,2,0))
    plt.imshow(npimg)

# %%
show_img("Real",X_train,size = 32)
# Out:
# Real

# %%
show_img("Generated",net(X_train[:32]),size = 32)
# Out:
# Generated

# %%
def blank_part_of_img(img,random=False,img_size=28):
    blanked_img = img.view(32,1,img_size,img_size).clone()
    blank_size = np.random.randint(2,15)
    if random == True:
        blank_indexes = np.random.randint(0,int(img_size/2),size=2)
    else:
        blank_indexes = np.array([0,0])
    blanked_img[
        :,:,
        blank_indexes[0]:blank_indexes[0]+blank_size,
        blank_indexes[1]:blank_indexes[1]+blank_size
    ] = 0.0
    return blanked_img.view(-1,X_dim)

def combine_tensors(X1,X2):
    X_concat = torch.cat((X1[:8],X2[:8]))
    return X_concat

# %%
X_blank                = blank_part_of_img(X_train[:32],random=True)
X_gen_from_blank       = net(X_blank).detach()
X_gen_from_real        = net(X_train[:32]).detach()
X_real_plus_blank      = combine_tensors(X_train,X_blank)
X_gen_blank_plus_blank = combine_tensors(X_gen_from_blank,X_blank)
X_real_plus_gen_real   = combine_tensors(X_train,X_gen_from_real)
X_real_plus_gen_blank  = combine_tensors(X_train,X_gen_from_blank)

# %%
show_img("X_real_plus_gen_blank",X_real_plus_gen_blank,size=16)
# Out:
# X_real_plus_gen_blank

# %%
show_img("X_real_plus_blank",X_real_plus_blank,size=16)
# Out:
# X_real_plus_blank

# %%
show_img("X_gen_blank_plus_blank",X_gen_blank_plus_blank,size=16)
# Out:
# X_gen_blank_plus_blank

# %%
show_img("X_real",X_train,size=32)
# Out:
# X_real

# %%
show_img("X_gen_from_real",X_gen_from_real)
# Out:
# X_gen_from_real

# %%
show_img("X_gen_from_blank",X_gen_from_blank,size=32)
# Out:
# X_gen_from_blank

# %%
show_img("X_blank",X_blank,size=32)
# Out:
# X_blank

# %% [markdown]
# ### Usando a norma dos pesos

# %%
class Net(nn.Module):
    def __init__(self,input_dim=784,output_dim=784,ngpu=ngpu):
        super(Net, self).__init__()
        self.input_dim = input_dim
        self.output_dim = output_dim
        self.hidden1 = nn.Linear(self.input_dim, self.output_dim)
        self.act1 = nn.ReLU()
        self.hidden2 = nn.Linear(self.output_dim, self.output_dim)
        self.act2 = nn.ReLU()
        self.out1 = nn.Linear(self.output_dim, self.output_dim)

    def forward(self, x):
        h = self.act1(self.hidden1(x))
        h = self.act2(self.hidden2(h))
        out = torch.sigmoid(self.out1(h))
        return out

def init_weights(m):
    if type(m) == nn.Linear:
        torch.nn.init.xavier_normal_(m.weight).to(device)
        m.bias.data.fill_(0.001)
    
def define_model():
    # Instanciamos as redes
    net = Net().to(device)
    if (device.type == 'cuda') and (ngpu > 1):
        net = nn.DataParallel(net, list(range(ngpu)))

    # Inicializamos os pesos
    net.apply(init_weights)

    learning_rate, beta1, beta2 = [1e-3,0.5,0.999]
    eps,weight_decay,amsgrad = [1e-8,0,False]
    net_optimizer = optim.Adam(net.parameters(),
                               lr=learning_rate,
                               betas=(beta1,beta2),
                               eps=eps,
                               weight_decay=weight_decay,
                               amsgrad=amsgrad)
    return net,net_optimizer

mse_loss = nn.MSELoss()

net,net_optimizer = define_model()

# %%
reg_lambda = 0.001
for epoch in range(10):
    loss_ = []
    for _, (X_train,_) in enumerate(train_loader):
        X_train = X_train.view(-1,784).to(device)
        X_pred_train = net(X_train)
        l2_reg = None
        for W in net.parameters():
            if l2_reg is None:
                l2_reg = W.norm(2)
            else:
                l2_reg = l2_reg + W.norm(2)
        loss = mse_loss(X_pred_train,X_train) + l2_reg * reg_lambda
        loss.backward()
        net_optimizer.step()
        net_optimizer.zero_grad()

    print("Training loss for {} epoch: {}".format(epoch, loss))
# Out:
# Training loss for 0 epoch: 0.051898397505283356
# Training loss for 1 epoch: 0.052472881972789764
# Training loss for 2 epoch: 0.05095183849334717
# Training loss for 3 epoch: 0.05180584266781807
# Training loss for 4 epoch: 0.05029278248548508
# Training loss for 5 epoch: 0.04783125966787338
# Training loss for 6 epoch: 0.0498909130692482
# Training loss for 7 epoch: 0.04894528165459633
# Training loss for 8 epoch: 0.05040367692708969
# Training loss for 9 epoch: 0.047442395240068436

# %%
show_img("Real",X_train,size = 32)
# Out:
# Real

# %%
show_img("Generated",net(X_train[:32]),size = 32)
# Out:
# Generated

# %%
show_adn_save("real",make_grid(X_train[:32].cpu().view(32,1,28,28).data))

# %%
show_adn_save("generate",make_grid(net(X_train[:32]).cpu().view(32,1,28,28).data))
